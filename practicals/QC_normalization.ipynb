# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc

# %%
# %matplotlib inline

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
sc.set_figure_params(dpi=80, figsize=(4,4))

sc.settings.verbosity=0

# %%
# Read cellranger files for all four samples
filename = './GSE132188_RAW/E12_5/matrix.mtx'
filename_genes = './GSE132188_RAW/E12_5/genes.tsv'
filename_barcodes = './GSE132188_RAW/E12_5/barcodes.tsv'

#cells should be as rows and genes as columns
e125 = sc.read(filename).transpose()

e125.var_names = np.genfromtxt(filename_genes, dtype=str)[:, 1]
e125.obs_names = np.genfromtxt(filename_barcodes, dtype=str)

# %%
e125
# Out:
# AnnData object with n_obs × n_vars = 11183 × 27998

# %%
e125.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCTGAGCACCGCT-1, AAACCTGAGCGCTTAT-1, AAACCTGAGGGAAACA-1, AAACCTGAGGTACTCT-1, AAACCTGAGTCACGCC-1, AAACCTGCAAATACAG-1, AAACCTGCACAACGCC-1, AAACCTGCACAAGCCC-1, AAACCTGCAGGACGTA-1, AAACCTGGTACGCACC-1, AAACCTGGTGTTTGGT-1, AAACCTGGTTCGGGCT-1, AAACCTGGTTCGTGAT-1, AAACCTGTCAATACCG-1, AAACCTGTCAGTCCCT-1, AAACCTGTCGAGAACG-1, AAACCTGTCTCAAACG-1, AAACCTGTCTTACCTA-1, AAACGGGAGCGTTGCC-1, AAACGGGAGGACACCA-1, AAACGGGCAAGAGGCT-1, AAACGGGCACACGCTG-1, AAACGGGCAGGGATTG-1, AAACGGGCAGTACACT-1, AAACGGGGTATGCTTG-1, AAACGGGGTCATATGC-1, AAACGGGGTTAGTGGG-1, AAACGGGGTTATGTGC-1, AAACGGGGTTCAGTAC-1, AAACGGGTCAACACCA-1, AAACGGGTCAACCATG-1, AAACGGGTCAGTGCAT-1, AAACGGGTCCAGGGCT-1, AAACGGGTCCTTGACC-1, AAACGGGTCGTGGGAA-1, AAACGGGTCTCTAAGG-1, AAACGGGTCTTGACGA-1, AAACGGGTCTTGCATT-1, AAAGATGAGAAGGTGA-1, AAAGATGAGAGTGACC-1, AAAGATGAGCCACCTG-1, AAAGATGAGCCCAACC-1, AAAGATGAGGGCTTGA-1, AAAGATGAGTCGCCGT-1, AAAGATGCAAAGGTGC-1, AAAGATGCACACGCTG-1, AAAGATGCACTCAGGC-1, AAAGATGCAGACGTAG-1, AAAGATGCAGTCAGAG-1, AAAGATGCATGCCTAA-1, AAAGATGCATTTCAGG-1, AAAGATGGTAAATGAC-1, AAAGATGGTAGGCTGA-1, AAAGATGGTATCAGTC-1, AAAGATGGTCATCGGC-1, AAAGATGGTCTGCGGT-1, AAAGATGGTCTTCAAG-1, AAAGATGGTGAGGCTA-1, AAAGATGGTGCAACTT-1, AAAGATGGTTAAGAAC-1, AAAGATGGTTATCGGT-1, AAAGATGGTTGATTGC-1, AAAGATGTCCGCGTTT-1, AAAGATGTCTCCA
filename_genes = './GSE132188_RAW/E13_5/genes.tsv'
filename_barcodes = './GSE132188_RAW/E13_5/barcodes.tsv'

e135 = sc.read(filename).transpose()
e135.var_names = np.genfromtxt(filename_genes, dtype=str)[:, 1]
e135.obs_names = np.genfromtxt(filename_barcodes, dtype=str)

# %%
e135
# Out:
# AnnData object with n_obs × n_vars = 5167 × 27998

# %%
filename = './GSE132188_RAW/E14_5/matrix.mtx'
filename_genes = './GSE132188_RAW/E14_5/genes.tsv'
filename_barcodes = './GSE132188_RAW/E14_5/barcodes.tsv'

e145 = sc.read(filename).transpose()
e145.var_names = np.genfromtxt(filename_genes, dtype=str)[:, 1]
e145.obs_names = np.genfromtxt(filename_barcodes, dtype=str)

# %%
e145
# Out:
# AnnData object with n_obs × n_vars = 10188 × 27998

# %%
filename = './GSE132188_RAW/E15_5/matrix.mtx'
filename_genes = './GSE132188_RAW/E15_5/genes.tsv'
filename_barcodes = './GSE132188_RAW/E15_5/barcodes.tsv'

e155 = sc.read(filename).transpose()
e155.var_names = np.genfromtxt(filename_genes, dtype=str)[:, 1]
e155.obs_names = np.genfromtxt(filename_barcodes, dtype=str)

# %%
e155
# Out:
# AnnData object with n_obs × n_vars = 11439 × 27998

# %%
# Add dev. timepoint label for each sample
e125.obs['day'] = '12.5'
e135.obs['day'] = '13.5'
e145.obs['day'] = '14.5'
e155.obs['day'] = '15.5'

# %%
e125.obs
# Out:
#                      day
# AAACCTGAGCACCGCT-1  12.5
# AAACCTGAGCGCTTAT-1  12.5
# AAACCTGAGGGAAACA-1  12.5
# AAACCTGAGGTACTCT-1  12.5
# AAACCTGAGTCACGCC-1  12.5
# ...                  ...
# TTTGTCAGTTTGACAC-1  12.5
# TTTGTCATCAGCCTAA-1  12.5
# TTTGTCATCATCATTC-1  12.5
# TTTGTCATCTACGAGT-1  12.5
# TTTGTCATCTCGTATT-1  12.5
#
# [11183 rows x 1 columns]

# %%
#create a list of four anndata objects
adatas=[e125, e135, e145, e155]

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 11183 × 27998
#      obs: 'day',
#  AnnData object with n_obs × n_vars = 5167 × 27998
#      obs: 'day',
#  AnnData object with n_obs × n_vars = 10188 × 27998
#      obs: 'day',
#  AnnData object with n_obs × n_vars = 11439 × 27998
#      obs: 'day']

# %%
#making observation and variable names unique for each anndata object
for i, adata in enumerate(adatas):
    # Reset index with a suffix to ensure uniqueness
    adata.obs_names_make_unique(join='-')
    adata.var_names_make_unique(join='-')

# %%
# Create Concatenated anndata object for all timepoints
adata = adatas[0].concatenate(adatas[1:], batch_key='batch', index_unique='-')
# Deleting individual day arrays
del e125
del e135
del e145
del e155

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 37977 × 27998
#     obs: 'day', 'batch'

# %%
# mitochondrial genes
adata.var["mt"] = adata.var_names.str.startswith("mt-")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 37977 × 27998
#     obs: 'day', 'batch'
#     var: 'mt'

# %%
adata.var['mt'].value_counts()
# Out:
# mt
# False    27985
# True        13
# Name: count, dtype: int64

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 37977 × 27998
#     obs: 'day', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'

# %%
sc.pl.violin(adata, keys=["n_genes_by_counts"])
sc.pl.violin(adata, keys=["total_counts"])
sc.pl.violin(adata, keys=["pct_counts_mt"])

# %%
sns.displot(adata.obs["total_counts"], bins=100, kde=False)

# %%
sns.displot(adata.obs["log1p_total_counts"], bins=100, kde=False)

# %%
# #counts per cell
adata.obs['n_counts'] = adata.X.sum(1)
# #logcounts per cell
adata.obs['log_counts'] = np.log(adata.obs['n_counts'])
# #genes per cell
adata.obs['n_genes'] = (adata.X > 0).sum(1)
# mitochondrial gene fraction
mt_gene_mask = [gene.startswith('mt-') for gene in adata.var_names]
mt_gene_index = np.where(mt_gene_mask)[0]
adata.obs['mt_frac'] = adata.X[:,mt_gene_index].sum(1) / adata.X.sum(1)

# %%
adata

# %%
adata.raw=adata.copy()

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
adata = adata[adata.obs['mt_frac'] < 0.2]
print('Number of cells after MT filter: {:d}'.format(adata.n_obs))

sc.pp.filter_cells(adata, min_genes = 1200)
print('Number of cells after gene filter: {:d}'.format(adata.n_obs))
#Filter genes:
print('Total number of genes: {:d}'.format(adata.n_vars))

# Min 20 cells - filters out 0 count genes
sc.pp.filter_genes(adata, min_cells=20)
print('Number of genes after cell filter: {:d}'.format(adata.n_vars))
# Out:
# Total number of cells: 37932
# Number of cells after MT filter: 37932
# Number of cells after gene filter: 37932
# Total number of genes: 17327
# Number of genes after cell filter: 17327

# %%
adata.layers["raw-counts"]=adata.X.copy()

# %%
sc.pp.scrublet(adata, batch_key="batch")

# %%
adata

# %%
sc.pp.normalize_total(adata, inplace=True)
sc.pp.log1p(adata)

# %%
adata.X.toarray()
# Out:
# array([[0.        , 1.2654365 , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.4410176 , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.313427  , 0.8584278 , ..., 0.        , 0.5186296 ,
#         0.        ],
#        ...,
#        [0.        , 0.75080025, 0.75080025, ..., 1.1747673 , 0.        ,
#         0.        ],
#        [0.        , 1.0562365 , 0.        , ..., 1.5583671 , 0.        ,
#         0.        ],
#        [0.        , 0.8100115 , 0.4848719 , ..., 0.4848719 , 1.2515817 ,
#         0.        ]], dtype=float32)

# %%
adata.layers["logcounts"]=adata.X.copy()

# %%
sc.pp.highly_variable_genes(adata, batch_key="batch", n_top_genes=4000)

# %%
adata

# %%
ax = sns.scatterplot(
    data=adata.var, x="means", y="dispersions", hue="highly_variable", s=5
)
ax.set_xlim(None, 1.5)
ax.set_ylim(None, 3)
plt.show()

# %%
adata.write("pan_endo.h5ad")
